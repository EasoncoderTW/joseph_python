# %% [markdown]
# ## Knight's Tour Problem - WARNSDORFF algorithm with dynamic degree-updating

# %%
# Knight's Tour Problem - WARNSDORFF algorithm with dynamic degree-updating
def knightTour(ni, nj, xi, xj):
    # STEP 1 : Creating a degree map by the WARNSDORFF rules...
    degree_map = [2,3,4,4,4,4,3,2,
                  3,4,6,6,6,6,4,3,
                  4,6,8,8,8,8,6,4,
                  4,6,8,8,8,8,6,4,
                  4,6,8,8,8,8,6,4,
                  4,6,8,8,8,8,6,4,
                  3,4,6,6,6,6,4,3,
                  2,3,4,4,4,4,3,2]
    # knight_map = degree_map
    
    for i in range(ni*nj):
        if i%8 < 7:
            print(degree_map[i], end=' ')
        else: 
            print(degree_map[i])

    # STEP 2 : Creating the 8 possible moves...
    eight_moves = [(1,-2),(2,-1),(2,1),(1,2),(-1,2),(-2,1),(-2,-1),(-1,-2)]
    for i in range(8):
        print(eight_moves[i], end=' ')
    print('\n')
    
    # STEP 3 : Initiating the start position of Knight...
    knight_move = ni*nj

    # STEP 4 : Looping for finding the Hamiltonian Path for Knight’s Tour...
    for _ in range(knight_move-1):
        if knight_move == ni*nj:
            degree_map[xi*8+xj] = knight_move

        # (1) Checking if the moves within the board boundaries or not...
        OK_moves = []
        for i in range(8):
            (test_i, test_j) = (xi + eight_moves[i][0], xj + eight_moves[i][1])
            if test_i >= 0 and test_j >= 0 and test_i <= 7 and test_j <= 7:
                OK_moves.append((test_i, test_j))
        # print(OK_moves)

        # (2) Finding the next position for Knight's movement...
        count = 0
        for ti,tj in OK_moves:
            # print(degree_map[ti*8+tj], end=' ')
            if degree_map[ti*8+tj] >= ni*nj:
                continue
            elif count == 0:
                temp = ti, tj, degree_map[ti*8+tj]
                count += 1
            elif degree_map[ti*8+tj] < temp[2]:
                temp = ti, tj, degree_map[ti*8+tj]
        # print(temp)
        
        # (3) Updating the degree map and the new move...
        for ti,tj in OK_moves:
            if degree_map[ti*8+tj] >= ni*nj:
                continue
            else: 
                degree_map[ti*8+tj] -= 1

        knight_move += 1
        degree_map[temp[0]*8+temp[1]] = knight_move
        xi, xj = temp[0], temp[1]
        # print(degree_map[temp[0]*8+temp[1]], xi, xj, temp[2])
    
    # STEP 5 : Print out the Hamiltonian Path for Knight’s Tour...
    for i in range(ni*nj):
        if i%8 < 7:
            print('{0:3d}'.format(degree_map[i]-ni*nj+1), end=' ')
        else: 
            print('{0:3d}'.format(degree_map[i]-ni*nj+1))    
    
knightTour(8,8,3,2)

# %%
def knightTour(ni, nj, xi, xj):
    degree_map = [2,3,4,4,4,4,3,2,3,4,6,6,6,6,4,3,4,6,8,8,8,8,6,4,4,6,8,8,8,8,6,4,4,6,8,8,8,8,6,4,4,6,8,8,8,8,6,4,3,4,6,6,6,6,4,3,2,3,4,4,4,4,3,2]
    print("".join([str(degree_map[i])+" " if i%8 < 7 else str(degree_map[i])+"\n" for i in range(ni*nj)]))
    eight_moves = [(1,-2),(2,-1),(2,1),(1,2),(-1,2),(-2,1),(-2,-1),(-1,-2)]
    print("".join([str(eight_moves[i])+" "  for i in range(8)]), end = "\n\n")
    knight_move = ni*nj
    for _ in range(knight_move-1):
        degree_map[xi*8+xj] = knight_move if knight_move == ni*nj else degree_map[xi*8+xj]
        OK_moves = [(xi + eight_moves[i][0], xj + eight_moves[i][1]) for i in range(8) if (xi + eight_moves[i][0]) >= 0 and (xj+eight_moves[i][1]) >= 0 and (xi + eight_moves[i][0]) <= 7 and (xj+eight_moves[i][1]) <= 7]
        OK_moves = [(ti,tj) for ti,tj in OK_moves if (degree_map[ti*8+tj] < ni*nj)]
        OK_moves.sort(key=lambda x:degree_map[x[0]*8+x[1]])
        temp = OK_moves[0]
        for ti,tj in OK_moves:
            degree_map[ti*8+tj] -= 1 
        knight_move += 1
        degree_map[temp[0]*8+temp[1]] = knight_move
        xi, xj = temp[0], temp[1]
    print("".join(['{0:3d}'.format(degree_map[i]-ni*nj+1)+" " if i%8 < 7 else '{0:3d}'.format(degree_map[i]-ni*nj+1)+"\n" for i in range(ni*nj) ]))
knightTour(8,8,3,2)
# Out:
# 2 3 4 4 4 4 3 2
# 3 4 6 6 6 6 4 3
# 4 6 8 8 8 8 6 4
# 4 6 8 8 8 8 6 4
# 4 6 8 8 8 8 6 4
# 4 6 8 8 8 8 6 4
# 3 4 6 6 6 6 4 3
# 2 3 4 4 4 4 3 2
#
# (1, -2) (2, -1) (2, 1) (1, 2) (-1, 2) (-2, 1) (-2, -1) (-1, -2)
#
#  56  31  14  43  64  29  12  41
#  15  44  57  30  13  42  61  28
#  32  55  46  53  60  63  40  11
#  45  16   1  58  39  52  27  62
#   2  33  54  47  20  59  10  37
#  17  48  21  34  51  38   7  26
#  22   3  50  19  24   5  36   9
#  49  18  23   4  35   8  25   6
