# %% [markdown]
# # PART II   < Python Data Analysis >
#
# # 12. Data Visualization with `matplotlib` and `Seaborn`
#
# _C. Alex Hu, PhD @  2023/01/08_
#
# >
# > **[ REFERENCE ] :**
# >
# > 1. **Matplotlib - Tutorials :** https://matplotlib.org/tutorials/index.html
# >      + [ Code ] => Github : https://github.com/matplotlib/matplotlib
# >
# >
# > 2. **Jake VanderPlas, "Python Data Science Handbook", Ch. 4 "Visualization with Matplotlib", O'Reilly, 2017.**
# > https://github.com/jakevdp/PythonDataScienceHandbook
# >
# >
# > 3. **Seaborn: statistical data visualization - User guide and tutorial**
#  http://seaborn.pydata.org/tutorial.html
#
#  ------------------------------------------------

# %% [markdown]
# ## CONTENT:
#
# + [1. Data Visualization with `matplotlib`](#matplotlib)
#    - [1.1 Pyplot](#Pyplot)
#    - [1.2 Animated Plots](#Animated_Plots)
#    - [1.3 3D Plots](#3D_Plots)
#    - [1.4 Images](#Images)
#
#
# + [2. Data Visualization with `Seaborn`](#Seaborn)
#    - [2.1 `matplotlib` working with `Seaborn`](#working_with_Seaborn)
#    - [2.2 Visualizing Raw Data with `Seaborn` `pairplot()`](#RawData)
#    - [2.3 Visualizing Statistical Data](#StatisticalData)
#
#
# + [3. Simple Linear Regression - Data Visualization](#SimpleLinearRegression)

# %% [markdown]
# <a id='matplotlib'></a>
# # 1. Data Visualization with `matplotlib`

# %% [markdown]
# <a id='Pyplot'></a>
# ## 1.1 Pyplot
#
#  - An introduction to the pyplot interface.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot([10, 20, 30, 40, 50])
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
# 2-dataset plotting...

plt.plot([10, 20, 30, 40], [15, 20, 35, 55]);

# %%
# a color string + a marker style + a line style string, 
# e.g., 'b-': a solid blue line.

plt.plot([10, 20, 30, 40], [15, 20, 35, 55], 'rs--')
plt.axis([0, 50, 10, 60])
plt.show()

# %% [markdown]
# + ### Plotting NumPy Arrays...

# %%
import numpy as np

# %%
# evenly sampled time at 250ms intervals
x = np.arange(0., 6., 0.25)

# green dashes, red squares solid and blue triangles 
plt.plot(x, x, 'g--', x, x**2, 'rs-', x, 2**x, 'b^')
plt.show()

# %% [markdown]
# + ### Plotting with keyword strings...
# -----------
#     matplotlib.pyplot.scatter(x, y, s=None, c=None,
#                               marker=None, cmap=None,
#                               norm=None, vmin=None,
#                               vmax=None, alpha=None,
#                               linewidths=None, *,
#                               edgecolors=None,
#                               plotnonfinite=False,
#                               data=None, **kwargs)
#
#    **[ Ref ]: `matplotlib.pyplot.scatter`:** https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html

# %%
# Plotting with keyword strings...
covid_19 = {'Countries': np.arange(20),
            'GDP Growth Rate': np.random.randn(20),
            'Vaccined': np.random.randint(0, 100, 20).astype('float'),
            'Population': 1000 * np.random.rand(20)}

# [Note]: `matplotlib.pyplot.scatter`
#         cmap is only used if c is an array of floats.
#         (default: 'viridis')
plt.scatter('Countries', 'GDP Growth Rate', 
            c='Vaccined', s='Population', 
            cmap='viridis', data=covid_19)
plt.xlabel('Countries')
plt.ylabel('GDP Growth Rate (%)')
plt.grid()
plt.colorbar()
plt.show()

# %% [markdown]
# + ### Plotting with categorical variables...

# %%
# Plotting with categorical variables...
countries = ['A', 'B', 'C']
GDP_GR = [2.2, 1.5, 5.9]

plt.figure(1, figsize=(9, 3))
plt.subplot(131)
plt.bar(countries, GDP_GR)
plt.subplot(132)
plt.scatter(countries, GDP_GR)
plt.subplot(133)
plt.plot(countries, GDP_GR)
plt.suptitle('GDP Growth Rate (%)')
plt.show()

# %% [markdown]
# + **[NOTE]:** *Controlling line properties, referred to `[Ref. 1]`.*

# %% [markdown]
# + ### Working with multiple figures and axes...

# %%
def f(t):
    mu = np.mean(t)
    return np.exp(-(t-mu)**2/(2*np.pi))

t1 = np.arange(0.0, 51.0, 1)     #  51 points
t2 = np.arange(0.0, 50.5, 0.5)   # 101 points

plt.figure(1)
plt.subplot(211)
plt.plot(t1, f(t1), 'go', t2, f(t2), 'k')

plt.subplot(212)
plt.plot(t2/10, np.sin(2*np.pi*t2/10) + np.random.rand(101), 'bo-')
plt.show()

# %% [markdown]
# + ### Plotting logarithmic axes

# %%
# Logarithmic axes
x = np.linspace(0, 1)
# y = np.power(10, x)    # y = np.exp(x)
y = np.exp(x)

plt.figure(1, [7,5])

# linear plot
plt.subplot(221)
plt.plot(x, y)
plt.yscale('linear')
plt.title('linear scale on both')
plt.axis([0, 1, 0, 11])
plt.grid(True);

# log-scale plot
plt.subplot(222)
plt.plot(x, y)
plt.yscale('log')
plt.title('log scale on y-axis')
plt.grid(True)
plt.show()

# %% [markdown]
# + ### Adding mathematical expressions in text & Annotating text

# %%
from scipy.stats import norm

# Working with text...
mu, sigma = 70, 15
x = mu + sigma * np.random.randn(5000)

# the histogram of the data
plt.hist(x, 50, density=1, facecolor='g', alpha=1.0)
plt.xlabel('Weight (kgw)')
plt.ylabel('Probability (%)')
plt.title('Histogram of Weight (kgw)')
# Adding the text to the figure...
plt.text(85, .02, r'$\mu=70 kg,\ \sigma=15$')

# Plot the normal distribution...
x_axis = np.arange(10, 130, 0.01)
# Adding an anotation to the figure...
plt.plot(x_axis, norm.pdf(x_axis, mu, sigma), 'r')
plt.annotate('peak value', xy=(70, 0.027), xytext=(85, 0.03),
             arrowprops=dict(facecolor='b', shrink=0.02))

plt.axis([10, 130, 0, 0.035])
plt.grid(True)
plt.show()

# %% [markdown]
# <a id='Animated_Plots'></a>
# ## 1.2 Animated Plots
#
# + ### [ Paradigm ]: Animated histogram
#
# > **[Ref]: Animated histogram -**
# https://matplotlib.org/stable/gallery/animation/animated_histogram.html#sphx-glr-gallery-animation-animated-histogram-py

# %%
import matplotlib.animation as animation
from IPython.display import HTML

# Fixing random seed...
np.random.seed(20210524)

# Fixing bin edges: 0:00am ~ 12:00pm
bins = np.linspace(0, 12, 100)

# histogram for the numpy data...
loc, scale, size = 8, 1, 1000
traffic = np.random.normal(loc=8, scale=1, size=1000) 
n, _ = np.histogram(traffic, bins)

# %% [markdown]
# + **Creating the traffic flows for 100 days**

# %%
def pre_animation(bar_container, loc=8, scale=1, size=1000):  
    def animate(frames):
        # Traffic-flow data simulation for each day...
        traffic = np.random.normal(loc, scale, size)  
        n, _ = np.histogram(traffic, bins)
        for count, rect in zip(n, bar_container.patches):
            rect.set_height(count)
        return bar_container.patches
    return animate

# %% [markdown]
# + **Animating the traffic flows**

# %%
fig, ax = plt.subplots()
n, _, bars = ax.hist(traffic, bins, lw=1,
                              ec="yellow", fc="red", alpha=0.75)
ax.set_ylim(top=70)  # setting y-axis limit 
plt.title('Traffic Flows from 0am~12pm - First Quarter')
plt.ylabel('Numbers of Autos')
plt.xlabel('hours (AM)')

# A 100-day-traffic-flow animation ...
ani = animation.FuncAnimation(fig, 
                              pre_animation(bars, loc, scale, size), 
                              frames=100, repeat=False, blit=True)

HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img1253c869e10e4b8b8b2a049f17575104">
#   <div class="anim-controls">
#     <input id="_anim_slider1253c869e10e4b8b8b2a049f17575104" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim1253c869e10e4b8b8b2a049f17575104.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" onclick="anim1253c869e10e4b8b8b2a049f17575104.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" onclick="anim1253c869e10e4b8b8b2a049f17575104.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" onclick="anim1253c869e10e4b8b8b2a049f17575104.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" onclick="anim1253c869e10e4b8b8b2a049f17575104.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" onclick="anim1253c869e10e4b8b8b2a049f17575104.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" onclick="anim1253c869e10e4b8b8b2a049f17575104.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" onclick="anim1253c869e10e4b8b8b2a049f17575104.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" onclick="anim1253c869e10e4b8b8b2a049f17575104.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" onclick="anim1253c869e10e4b8b8b2a049f17575104.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" action="#n" name="_anim_loop_select1253c869e10e4b8b8b2a049f17575104"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_1253c869e10e4b8b8b2a049f17575104"
#              checked>
#       <label for="_anim_radio1_1253c869e10e4b8b8b2a049f17575104">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_1253c869e10e4b8b8b2a049f17575104"
#              >
#       <label for="_anim_radio2_1253c869e10e4b8b8b2a049f17575104">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_1253c869e10e4b8b8b2a049f17575104"
#              >
#       <label for="_anim_radio3_1253c869e10e4b8b8b2a049f17575104">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img1253c869e10e4b8b8b2a049f17575104";
#     var slider_id = "_anim_slider1253c869e10e4b8b8b2a049f17575104";
#     var loop_select_id = "_anim_loop_select1253c869e10e4b8b8b2a049f17575104";
#     var frames = new Array(100);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjMuMiwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8vihELAAAACXBIWXMAAAsT\
# AAALEwEAmpwYAAAiAUlEQVR4nO3debgcVbnv8e+PBGSWICGEIUQgAoICGlFEBQ1hUBQ8iDIHxZvj\
# gHKUA0Sv5wDq9aIIBz0cUVQwIKAIKMggQ2QQRSZlNHADIYRATAIGE5AACe/9Y602laZ39tS1q2vv\
# 3+d5+umq6hre6q7ut9eqVasUEZiZmdXNKlUHYGZm1hdOYGZmVktOYGZmVktOYGZmVktOYGZmVktO\
# YGZmVktOYGZmVktOYGZmVktOYGZmV

# %% [markdown]
# <a id='3D_Plots'></a>
# ## 1.3 3D Plots
#
# > **[Ref]: `mplot3d` tutorial -**
# https://matplotlib.org/2.0.2/mpl_toolkits/mplot3d/tutorial.html

# %%
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# + **Line Plots**

# %%
# Setting the legend font size...
mpl.rcParams['legend.fontsize'] = 10 

fig = plt.figure()
ax = fig.gca(projection='3d')
num = 180
theta = np.linspace(-5*np.pi, 5*np.pi, num)
z = np.linspace(0, 1, num)
r = z
x = r * np.sin(theta + np.pi/2)
y = r * np.cos(theta + np.pi/2)

ax.plot(x, y, z, label='Spiral curve : z = r')
plt.xlabel(r'$x = r*sin(\theta + \pi/2)$')
plt.ylabel(r'$y = r*cos(\theta + \pi/2)$')
ax.legend()
plt.show()

# %% [markdown]
# + **Scatter Plots**

# %%
fig = plt.figure(1, [9, 4])
num = 100

ax = fig.add_subplot(121, projection='3d')
for i in range(2):
    xs = np.random.randn(num) * 10
    ys = np.random.randn(num) 
    zs = i
    ax.scatter(xs, ys, zs, 
               c='b' if i == 0 else 'r', 
               marker='o' if i == 0 else '^')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

ax = fig.add_subplot(122, projection='3d')
for i in range(2):
    xs = np.random.randn(num) * 10
    ys = np.random.randn(num) 
    zs = np.sqrt(xs**2 + ys**2)
    ax.scatter(xs, ys, zs, 
               c='b' if i == 0 else 'r', 
               marker='o' if i == 0 else '^')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.show()

# %% [markdown]
# + **Surface Plots**

# %%
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter

fig = plt.figure(1, [4,8])
ax = fig.gca(projection='3d')

X = np.arange(-2, 2, 0.05)
Y = np.arange(-2, 2, 0.05)
X, Y = np.meshgrid(X, Y)
Z = X**2 + Y**2      # Creating a paraboloid...

# Plotting the surface...
surf_plot = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

# Setting the z range...
ax.set_zlim(0, 7)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

# Adding a color bar...
fig.colorbar(surf_plot, shrink=0.5, aspect=15, 
             orientation='horizontal')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.show()

# %% [markdown]
# <a id='Images'></a>
# ## 1.4 Images

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %% [markdown]
# + ### Importing the image data...
#
# > - Importing image data, `stinkbug.png`, into Numpy arrays: https://raw.githubusercontent.com/matplotlib/matplotlib/master/doc/_static/stinkbug.png
# >
# >
# > - A 24-bit `RGB` PNG image (8 bits for each of R, G, B channels).
# >
# >
# > - **[NOTE] :**
#      + Natively, Matplotlib only supports PNG images.
#      + `RGBA` images, which allow for transparency, or single-channel grayscale (luminosity) images.

# %%
image_url = 'https://raw.githubusercontent.com/matplotlib/matplotlib/master/doc/_static/stinkbug.png'
image = mpimg.imread(image_url)
image
# Out:
# array([[[0.40784314, 0.40784314, 0.40784314],
#         [0.40784314, 0.40784314, 0.40784314],
#         [0.40784314, 0.40784314, 0.40784314],
#         ...,
#         [0.42745098, 0.42745098, 0.42745098],
#         [0.42745098, 0.42745098, 0.42745098],
#         [0.42745098, 0.42745098, 0.42745098]],
#
#        [[0.4117647 , 0.4117647 , 0.4117647 ],
#         [0.4117647 , 0.4117647 , 0.4117647 ],
#         [0.4117647 , 0.4117647 , 0.4117647 ],
#         ...,
#         [0.42745098, 0.42745098, 0.42745098],
#         [0.42745098, 0.42745098, 0.42745098],
#         [0.42745098, 0.42745098, 0.42745098]],
#
#        [[0.41960785, 0.41960785, 0.41960785],
#         [0.41568628, 0.41568628, 0.41568628],
#         [0.41568628, 0.41568628, 0.41568628],
#         ...,
#         [0.43137255, 0.43137255, 0.43137255],
#         [0.43137255, 0.43137255, 0.43137255],
#         [0.43137255, 0.43137255, 0.43137255]],
#
#        ...,
#
#        [[0.4392157 , 0.4392157 , 0.4392157 ],
#         [0.43529412, 0.43529412, 0.43529412],
#         [0.43137255, 0.43137255, 0.43137255],
#         ...,
#         [0.45490196, 0.45490196, 0.45490196],
#         [0.4509804 , 0.4509804 , 0.4509804 ],
#         [0.4509804 , 0.4509804 , 0.4509804 ]],
#
#        [[0.44313726, 0.44313726, 0.44313726],
#         [0.44313726, 0.44313726, 0.44313726],
#         [0.4392157 , 0.4392157 , 0.4392157 ],
#         ...,
#         [0.4509804 , 0.4509804 , 0.4509804 ],
#         [0.44705883, 0.44705883, 0.44705883],
#         [0.44705883, 0.44705883, 0.44705883]],
#
#        [[0.44313726, 0.44313726, 0.44313726],
#         [0.4509804 , 0.4509804 , 0.4509804 ],
#         [0.4509804 , 0.4509804 , 0.4509804 ],
#         ...,
#         [0.44705883, 0.44705883, 0.44705883],
#         [0.44705883, 0.44705883, 0.44705883],
#         [0.44313726, 0.44313726, 0.44313726]]], dtype=float32)

# %% [markdown]
# ### [ Note ] :
# - The dtype there - float32.
# - #### Matplotlib has rescaled the 8 bit data from each channel to floating point data between 0.0 and 1.0.
# - Matplotlib plotting can handle float32 and uint8, but image reading/writing for any format other than PNG is limited to uint8 data.
# - #### Each inner list represents a pixel.
# - Since it's a black and white image, R, G, and B are all similar.
#
# - **For RGB and RGBA images, matplotlib supports float32 and uint8 data types.**
# - **For grayscale, matplotlib supports only float32.**

# %%
imgplot = plt.imshow(image)

# %% [markdown]
# + ### Plotting any numpy array...
#
# + #### Applying pseudocolor schemes to image plots
# > - Pseudocolor => enhancing contrast to visualize your data more easily.
# > - Pseudocolor is only for single-channel, grayscale, luminosity images.

# %%
image[:, :, 0]   # It is only one-channel data.
# Out:
# array([[0.40784314, 0.40784314, 0.40784314, ..., 0.42745098, 0.42745098,
#         0.42745098],
#        [0.4117647 , 0.4117647 , 0.4117647 , ..., 0.42745098, 0.42745098,
#         0.42745098],
#        [0.41960785, 0.41568628, 0.41568628, ..., 0.43137255, 0.43137255,
#         0.43137255],
#        ...,
#        [0.4392157 , 0.43529412, 0.43137255, ..., 0.45490196, 0.4509804 ,
#         0.4509804 ],
#        [0.44313726, 0.44313726, 0.4392157 , ..., 0.4509804 , 0.44705883,
#         0.44705883],
#        [0.44313726, 0.4509804 , 0.4509804 , ..., 0.44705883, 0.44705883,
#         0.44313726]], dtype=float32)

# %%
img1 = image[:, :, 0]  # It is only one-channel data.
plt.imshow(img1)

# %%
print(image.shape)
print(img1.shape)
# Out:
# (375, 500, 3)
# (375, 500)

# %%
# The default colormap: 'viridis'  
# https://matplotlib.org/stable/tutorials/colors/colormaps.html
plt.imshow(img1, cmap="hot")

# %%
imgplot = plt.imshow(img1)
imgplot.set_cmap('nipy_spectral')

# %% [markdown]
# + ### Adding a Color Bar...

# %%
imgplot = plt.imshow(img1)
plt.colorbar()

# %% [markdown]
# + ### Examining a specific data range...

# %%
# Examining a specific data range with a histogram plot...
plt.hist(img1.ravel(), bins=256, range=(0.0, 1.0), fc='r', ec='b')
# Out:
# (array([2.000e+00, 2.000e+00, 3.000e+00, 3.000e+00, 2.000e+00, 2.000e+00,
#         3.000e+00, 1.000e+00, 7.000e+00, 9.000e+00, 7.000e+00, 2.000e+00,
#         7.000e+00, 1.000e+01, 1.100e+01, 1.500e+01, 1.400e+01, 2.700e+01,
#         2.100e+01, 2.400e+01, 1.400e+01, 3.100e+01, 2.900e+01, 2.800e+01,
#         2.400e+01, 2.400e+01, 4.000e+01, 2.600e+01, 5.200e+01, 3.900e+01,
#         5.700e+01, 4.600e+01, 8.400e+01, 7.600e+01, 8.900e+01, 8.000e+01,
#         1.060e+02, 1.130e+02, 1.120e+02, 9.000e+01, 1.160e+02, 1.090e+02,
#         1.270e+02, 1.350e+02, 9.800e+01, 1.310e+02, 1.230e+02, 1.110e+02,
#         1.230e+02, 1.160e+02, 1.010e+02, 1.170e+02, 1.000e+02, 1.010e+02,
#         9.000e+01, 1.060e+02, 1.260e+02, 1.040e+02, 1.070e+02, 1.110e+02,
#         1.380e+02, 1.000e+02, 1.340e+02, 1.210e+02, 1.400e+02, 1.320e+02,
#         1.390e+02, 1.160e+02, 1.330e+02, 1.180e+02, 1.080e+02, 1.170e+02,
#         1.280e+02, 1.200e+02, 1.210e+02, 1.100e+02, 1.160e+02, 1.180e+02,
#         9.700e+01, 9.700e+01, 1.140e+02, 1.070e+02, 1.170e+02, 8.700e+01,
#         1.070e+02, 9.800e+01, 1.040e+02, 1.120e+02, 1.110e+02, 1.180e+02,
#         1.240e+02, 1.340e+02, 1.200e+02, 1.410e+02, 1.520e+02, 1.360e+02,
#         1.610e+02, 1.380e+02, 1.620e+02, 1.570e+02, 1.350e+02, 1.470e+02,
#         1.690e+02, 1.710e+02, 1.820e+02, 1.980e+02, 1.970e+02, 2.060e+02,
#         2.160e+02, 2.460e+02, 2.210e+02, 2.520e+02, 2.890e+02, 3.450e+02,
#         3.620e+02, 3.760e+02, 4.480e+02, 4.630e+02, 5.170e+02, 6.000e+02,
#         6.200e+02, 6.410e+02, 7.440e+02, 7.120e+02, 8.330e+02, 9.290e+02,
#         1.061e+03, 1.280e+03, 1.340e+03, 1.638e+03, 1.740e+03, 1.953e+03,
#         2.151e+03, 2.290e+03, 2.440e+03, 2.758e+03, 2.896e+03, 3.384e+03,
#         4.332e+03, 5.584e+03, 6.197e+03, 6.422e+03, 6.404e+03, 7.181e+03,
#         8.196e+03, 7.968e+03, 7.474e+03, 7.926e+03, 8.460e+03, 8.091e+03,
#         9.148e+03, 8.563e+03, 6.747e+03, 6.074e+03, 6.328e+03, 5.291e+03,
#         6.472e+03, 6.268e+03, 2.864e+03, 3.760e+02, 1.620e+02, 1.180e+02,
#         1.270e+02, 9.500e+01, 7.600e+01, 8.200e+01, 6.200e+01, 6.700e+01,
#         5.600e+01, 5.900e+01, 4.000e+01, 4.200e+01, 3.000e+01, 3.400e+01,
#         3.200e+01, 4.300e+01, 4.200e+01, 2.300e+01, 2.800e+01, 1.900e+01,
#         2.200e+01, 1.600e+01, 1.200e+01, 1.800e+01, 9.000e+00, 1.000e+01,
#         1.700e+01, 5.000e+00, 2.100e+01, 1.300e+01, 8.000e+00, 1.200e+01,
#         1.000e+01, 8.000e+00, 8.000e+00, 5.000e+00, 1.300e+01, 6.000e+00,
#         3.000e+00, 7.000e+00, 6.000e+00, 2.000e+00, 1.000e+00, 5.000e+00,
#         3.000e+00, 3.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 5.000e+00,
#         0.000e+00, 1.000e+00, 3.000e+00, 0.000e+00, 1.000e+00, 1.000e+00,
#         2.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00]),
#  array([0.        , 0.00390625, 0.0078125 , 0.01171875, 0.015625  ,
#         0.01953125, 0.0234375 , 0.02734375, 0.03125   , 0.03515625,
#         0.0390625 , 0.04296875, 0.046875  , 0.05078125, 0.0546875 ,
#         0.05859375, 0.0625    , 0.06640625, 0.0703125 , 0.07421875,
#         0.078125  , 0.08203125, 0.0859375 , 0.08984375, 0.09375   ,
#         0.09765625, 0.1015625 , 0.10546875, 0.109375  , 0.11328125,
#         0.1171875 , 0.12109375, 0.125     , 0.12890625, 0.1328125 ,
#         0.13671875, 0.140625  , 0.14453125, 0.1484375 , 0.15234375,
#         0.15625   , 0.16015625, 0.1640625 , 0.16796875, 0.171875  ,
#         0.17578125, 0.1796875 , 0.18359375, 0.1875    , 0.19140625,
#         0.1953125 , 0.19921875, 0.203125  , 0.20703125, 0.2109375 ,
#         0.21484375, 0.21875   , 0.22265625, 0.2265625 , 0.23046875,
#         0.234375  , 0.23828125, 0.2421875 , 0.24609375, 0.25      ,
#         0.25390625, 0.2578125 , 0.26171875, 0.265625  , 0.26953125,
#         0.2734375 , 0.27734375, 0.28125   , 0.28515625, 0.2890625 ,
#         0.29296875, 0.296875  , 0.30078125, 0.3046875 , 0.30859375,
#         0.3125    , 0.31640625, 0.3203125 , 0.32421875, 0.328125  ,
#         0.33203125, 0.3359375 , 0.33984375, 0.34375   , 0.34765625,
#         0.3515625 , 0.35546875, 0.359375  , 0.36328125, 0.3671875 ,
#         0.37109375, 0.375     , 0.37890625, 0.3828125 , 0.38671875,
#         0.390625  , 0.39453125, 0.3984375 , 0.40234375, 0.40625   ,
#         0.41015625, 0.4140625 , 0.41796875, 0.421875  , 0.42578125,
#         0.4296875 , 0.43359375, 0.4375    , 0.44140625, 0.4453125 ,
#         0.44921875, 0.453125  , 0.45703125, 0.4609375 , 0.46484375,
#         0.46875   , 0.47265625, 0.4765625 , 0.48046875, 0.484375  ,
#         0.48828125, 0.4921875 , 0.49609375, 0.5       , 0.50390625,
#         0.5078125 , 0.51171875, 0.515625  , 0.51953125, 0.5234375 ,
#         0.52734375, 0.53125   , 0.53515625, 0.5390625 , 0.54296875,
#         0.546875  , 0.55078125, 0.5546875 , 0.55859375, 0.5625    ,
#         0.56640625, 0.5703125 , 0.57421875, 0.578125  , 0.58203125,
#         0.5859375 , 0.58984375, 0.59375   , 0.59765625, 0.6015625 ,
#         0.60546875, 0.609375  , 0.61328125, 0.6171875 , 0.62109375,
#         0.625     , 0.62890625, 0.6328125 , 0.63671875, 0.640625  ,
#         0.64453125, 0.6484375 , 0.65234375, 0.65625   , 0.66015625,
#         0.6640625 , 0.66796875, 0.671875  , 0.67578125, 0.6796875 ,
#         0.68359375, 0.6875    , 0.69140625, 0.6953125 , 0.69921875,
#         0.703125  , 0.70703125, 0.7109375 , 0.71484375, 0.71875   ,
#         0.72265625, 0.7265625 , 0.73046875, 0.734375  , 0.73828125,
#         0.7421875 , 0.74609375, 0.75      , 0.75390625, 0.7578125 ,
#         0.76171875, 0.765625  , 0.76953125, 0.7734375 , 0.77734375,
#         0.78125   , 0.78515625, 0.7890625 , 0.79296875, 0.796875  ,
#         0.80078125, 0.8046875 , 0.80859375, 0.8125    , 0.81640625,
#         0.8203125 , 0.82421875, 0.828125  , 0.83203125, 0.8359375 ,
#         0.83984375, 0.84375   , 0.84765625, 0.8515625 , 0.85546875,
#         0.859375  , 0.86328125, 0.8671875 , 0.87109375, 0.875     ,
#         0.87890625, 0.8828125 , 0.88671875, 0.890625  , 0.89453125,
#         0.8984375 , 0.90234375, 0.90625   , 0.91015625, 0.9140625 ,
#         0.91796875, 0.921875  , 0.92578125, 0.9296875 , 0.93359375,
#         0.9375    , 0.94140625, 0.9453125 , 0.94921875, 0.953125  ,
#         0.95703125, 0.9609375 , 0.96484375, 0.96875   , 0.97265625,
#         0.9765625 , 0.98046875, 0.984375  , 0.98828125, 0.9921875 ,
#         0.99609375, 1.        ], dtype=float32),
#  <BarContainer object of 256 artists>)

# %%
imgplot = plt.imshow(img1, clim=(0.0, 0.75))

# %%
def plots():
    fig = plt.figure()
    for i in range(2):
        a = fig.add_subplot(1, 2, i+1)
        imgplot = plt.imshow(img1)
        
        if i == 0:
            a.set_title('Original')
        else:
            a.set_title('Adjusted')
            imgplot.set_clim(0.0, 0.7) # setting the color limit
            
        plt.colorbar(ticks=[0.1, 0.3, 0.5, 0.7], 
                     orientation='horizontal')

plots()

# %% [markdown]
# + ### Download the image file from Web...

# %%
import requests

# image_url = 'https://raw.githubusercontent.com/matplotlib/matplotlib/master/doc/_static/stinkbug.png'
img_data = requests.get(image_url).content
with open('stinkbug.png', 'wb') as handler:
    handler.write(img_data)

# %% [markdown]
# + ### Using the `Pillow` library to resize the image...

# %%
from PIL import Image

img2 = Image.open('stinkbug.png')
img2.thumbnail((64, 64), Image.ANTIALIAS)  # resizes image in-place
imgplot = plt.imshow(img2)

# %% [markdown]
# + ### Array Interpolation schemes

# %%
# "nearest" : no interpolation.
imgplot = plt.imshow(img2, interpolation="nearest")

# %%
# Bicubic interpolation tends to prefer blurry over pixelated.
imgplot = plt.imshow(img2, interpolation="bicubic")

# %% [markdown]
# <a id='Seaborn'></a>
# # 2. Data Visualization with `Seaborn`

# %% [markdown]
# + **`Seaborn`** is a library for making statistical graphics in Python. [Ref 1](http://seaborn.pydata.org/tutorial.html)
#
#     + It builds on top of **`matplotlib`** and integrates closely with **`pandas`** data structures.
#
#     + **`Seaborn`** helps you explore and understand your data.
#
# > **[ Reference ] :**
# >
# >
# > 1. Seaborn - **An introduction to seaborn** http://seaborn.pydata.org/tutorial.html
# >
# > 2. Jake VanderPlas, **Python Data Science Handbook**, **Sec. 4.14 Visualization with Seaborn**, O'Reilly, 2017. https://github.com/jakevdp/PythonDataScienceHandbook
# >
# > 3. Wikipedia, **Simple Linear Regression**, https://en.wikipedia.org/wiki/Simple_linear_regression
# >

# %% [markdown]
# <a id='working_with_Seaborn'></a>
# ## 2.1 `matplotlib` working with `Seaborn`

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# + ### Using `matplotlib` `hist()` for plotting Multivariate Data Distributions

# %%
rnseed = np.random.RandomState(1)
data = rnseed.multivariate_normal([170, 180], [[5, 2], [2, 1]], 
                                     size=500)
data = pd.DataFrame(data, columns=['data1', 'data2'])

for _ in range(1,3):
    plt.hist(data['data'+str(_)], density=True, stacked=True, alpha=0.75)

# %% [markdown]
# + ### `matplotlib` working with `Seaborn.set()` to create better plots

# %%
import seaborn as sns
sns.set()

# %%
import seaborn as sns
sns.set()

# Running the same Pyplot statements
for _ in range(1,3):
    plt.hist(data['data'+str(_)], density=True, stacked=True, alpha=0.75)

# %% [markdown]
# <a id='RawData'></a>
# ## 2.2 Visualizing Raw Data with `Seaborn` `pairplot()`

# %% [markdown]
#  - ### Plot the numeric feature vaiables against each other by `pairplot()`.

# %%
import seaborn as sns
sns.set()   #  With sns.set()

# %%
iris_data = sns.load_dataset("iris")   # Iris dataset
iris_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# [NOTE]:  Without sns.set()
sns.pairplot(iris_data, hue='species', height=1.5)

# %% [markdown]
# <a id='StatisticalData'></a>
# ## 2.3 Visualizing Statistical Data

# %% [markdown]
# + ### `Seaborn` can plot KDE, Histograms, and ECDF plots.

# %%
import numpy as np
import pandas as pd

rnseed = np.random.RandomState(1)
data = rnseed.multivariate_normal([170, 180], [[5, 2], [2, 1]], 
                                     size=500)
data = pd.DataFrame(data, columns=['data1', 'data2'])

# %% [markdown]
# > - **`Kernel Density Estimation` (KDE)**
# >   +  "In statistics, kernel density estimation (KDE) is the application of kernel smoothing for probability density estimation, i.e., a non-parametric method to estimate the probability density function of a random variable based on kernels as weights."
# >   + "KDE answers a fundamental data smoothing problem where inferences about the population are made, based on a finite data sample." [from Wikipedia - KDE](https://en.wikipedia.org/wiki/Kernel_density_estimation)

# %%
# KDE (Kernel Density Estimation) plots
for _ in range(1,3):
    sns.kdeplot(data['data'+str(_)], shade=True);

# %% [markdown]
# > + **Plotting KDE and Histograms together with `histplot()`**

# %%
# < Method 1 >
for _ in range(1,3):
    sns.histplot(data['data'+str(_)], bins=10, kde=True, stat='density');

# %%
# < Method 2 >
sns.histplot(data, bins=20, kde=True, stat='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# > #### Q: Why both density ranges are different?  [ _Method 1 (0.4) vs. Method 2 (0.2)_ ]
# > [ Hint ]: Check with `kdeplot()` result !

# %%
for _ in range(1,3):
    sns.distplot(data['data'+str(_)]);
# Out:
# C:\Users\appcl\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\appcl\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# > + #### [ NOTE ] : `KDE` and `Normal Distribution` are different.
#
# > + **Normal (or Gaussian) Distribution**
# >
# >   $$ \frac{1}{\sqrt {2\pi} \sigma} \ e^{-\frac{(x-\mu)^2}{2 \sigma^2}} $$

# %% [markdown]
# <a id='SimpleLinearRegression'></a>
# # 3. Simple Linear Regression - Data Visualization

# %% [markdown]
# + ### Simple Linear Regression by _`Sir Francis Galton`_
#
# > **[ Reference ] :** Wikipedia, **Simple linear regression**, https://en.wikipedia.org/wiki/Simple_linear_regression
#
# > **< Simple Linear Regression > :**  $  y = a x + b $
# >
# >  1. Passing through the center of mass $ (\bar x, \bar y) $ of the data points :
# >
# >   $$ \bar y = a \bar x + b $$
# >
# >  2. The slope $ a $ :
# >
# >   $$ a = \frac{\sum_{i=1}^n (x_i - \bar x) (y_i - \bar y)}{\sum_{i=1}^n (x_i - \bar x)^2}
#          = \frac{Cov(x, y)}{Var(x)} $$
# ----------------------------

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

x_mean = data['data1'].mean()
y_mean = data['data2'].mean()
print('\n (x_mean, y_mean) = ({0}, {1})'.format(x_mean, y_mean))

with sns.axes_style('white'):
    sns.jointplot(x="data1", y="data2", data=data, kind='reg', 
                  ylim=[175, 185], xlim=[165, 175],
                  color=(0.8, 0.2, 0.2, 0.05), height=6, ratio=5);
    matplotlib.rcParams.update({'font.size': 20})
    plt.xlabel("Parent's Height")
    plt.ylabel("Kid's Height")
    plt.scatter(x_mean, y_mean, marker='P', c='k', s=200)
    plt.grid('true')
    plt.annotate(r'$ (\bar x, \bar y) $', xy=(x_mean, y_mean), xytext=(172, 177),
             arrowprops=dict(facecolor='blue', shrink=0.02))
    plt.text(179, 184, r'$ y = a x + b $')
    plt.text(179, 183, '_________ \n')
    plt.text(180, 182, r'$ \bar y = a \bar x + b $')
    plt.text(180, 179, r'$ a = \frac{\sum_{i=1}^n (x_i - \bar x) (y_i - \bar y)}{\sum_{i=1}^n (x_i - \bar x)^2} $',) 
    plt.text(180, 176, r'$ \quad  = \frac{Cov(x, y)}{Var(x)} $')
# Out:
#  (x_mean, y_mean) = (169.8908019059846, 179.96860451921341)

# %%
# x = 'data1' : Parent's Height
# y = 'data2' : Kid's Height
for _ in range(1,3):  
    sns.histplot(data['data'+str(_)], bins=20, kde=True, stat='density');
