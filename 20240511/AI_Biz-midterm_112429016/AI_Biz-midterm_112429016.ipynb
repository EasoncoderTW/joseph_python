# %%
from module1 import *
from module2 import *
from module3 import *
# Out:
# c:\Users\yoyoy\AppData\Local\Programs\Python\Python39\lib\site-packages\mpl_finance.py:16: DeprecationWarning:
#
#   =================================================================
#
#    WARNING: `mpl_finance` is deprecated:
#
#     Please use `mplfinance` instead (no hyphen, no underscore).
#
#     To install: `pip install --upgrade mplfinance`
#
#    For more information, see: https://pypi.org/project/mplfinance/
#
#   =================================================================
#
#   __warnings.warn('\n\n  ================================================================='+

# %%
# config
sid = "2330" # stock id
sql_name = "stock_data" # sql db name

# %%
# step 1
df = get_stock_datas(2020,1,2024,4,sid)
engine = store_to_sql(df,sql_name) # get returned engine
# Out:
# [Downloading] year = 2020, month =  1
# [Downloading] year = 2020, month =  2
# [Downloading] year = 2020, month =  3
# [Downloading] year = 2020, month =  4
# [Downloading] year = 2020, month =  5
# [Downloading] year = 2020, month =  6
# [Downloading] year = 2020, month =  7
# [Downloading] year = 2020, month =  8
# [Downloading] year = 2020, month =  9
# [Downloading] year = 2020, month = 10
# [Downloading] year = 2020, month = 11
# [Downloading] year = 2020, month = 12
# [Downloading] year = 2021, month =  1
# [Downloading] year = 2021, month =  2
# [Downloading] year = 2021, month =  3
# [Downloading] year = 2021, month =  4
# [Downloading] year = 2021, month =  5
# [Downloading] year = 2021, month =  6
# [Downloading] year = 2021, month =  7
# [Downloading] year = 2021, month =  8
# [Downloading] year = 2021, month =  9
# [Downloading] year = 2021, month = 10
# [Downloading] year = 2021, month = 11
# [Downloading] year = 2021, month = 12
# [Downloading] year = 2022, month =  1
# [Downloading] year = 2022, month =  2
# [Downloading] year = 2022, month =  3
# [Downloading] year = 2022, month =  4
# [Downloading] year = 2022, month =  5
# [Downloading] year = 2022, month =  6
# [Downloading] year = 2022, month =  7
# [Downloading] year = 2022, month =  8
# [Downloading] year = 2022, month =  9
# [Downloading] year = 2022, month = 10
# [Downloading] year = 2022, month = 11
# [Downloading] year = 2022, month = 12
# [Downloading] year = 2023, month =  1
# [Downloading] year = 2023, month =  2
# [Downloading] year = 2023, month =  3
# [Downloading] year = 2023, month =  4
# [Downloading] year = 2023, month =  5
# [Downloading] year = 2023, month =  6
# [Downloading] year = 2023, month =  7
# [Downloading] year = 2023, month =  8
# [Downloading] year = 2023, month =  9
# [Downloading] year = 2023, month = 10
# [Downloading] year = 2023, month = 11
# [Downloading] year = 2023, month = 12
# [Downloading] year = 2024, month =  1
# [Downloading] year = 2024, month =  2
# [Downloading] year = 2024, month =  3
# [Downloading] year = 2024, month =  4

# %%
# step 2
plot_stock_data(engine, sql_name, sid)

# %%
# step 3
plot_stock_data_with_moving_averages(engine, sql_name, sid, 60, 60)
